# %%
conda install pandas-datareader
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\ppaul\Anaconda3
#
#   added / updated specs:
#     - pandas-datareader
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.1                |           py37_0         2.8 MB
#     pandas-datareader-0.8.1    |             py_0          71 KB
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas-datareader  pkgs/main/noarch::pandas-datareader-0.8.1-py_0
#
# The following packages will be UPDATED:
#
#   conda                                       4.7.12-py37_0 --> 4.8.1-py37_0
#
#
#
# ...
#
# conda-4.8.1          | 2.8 MB    |            |   0%
# conda-4.8.1          | 2.8 MB    |            |   1%
# ...

# %%
import pandas_datareader.data as web

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = web.DataReader("AAPl","yahoo", start= "2015-9-1", end= "2019-12-31")

# %%
df
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2015-09-01  111.879997  107.360001  110.150002  107.720001  76845900.0
# 2015-09-02  112.339996  109.129997  110.230003  112.339996  61888800.0
# 2015-09-03  112.779999  110.040001  112.489998  110.370003  53233900.0
# 2015-09-04  110.449997  108.510002  108.970001  109.269997  49996300.0
# 2015-09-08  112.559998  110.320000  111.750000  112.309998  54843600.0
# ...                ...         ...         ...         ...         ...
# 2019-12-24  284.890015  282.920013  284.690002  284.269989  12119700.0
# 2019-12-26  289.980011  284.700012  284.820007  289.910004  23280300.0
# 2019-12-27  293.970001  288.119995  291.119995  289.799988  36566500.0
# 2019-12-30  292.690002  285.220001  289.459991  291.519989  36028600.0
# 2019-12-31  293.679993  289.519989  289.929993  293.649994  25201400.0
#
#              Adj Close
# Date
# 2015-09-01  100.232323
# 2015-09-02  104.531181
# 2015-09-03  102.698120
# ...

# %%
P = df['Adj Close']

# %%
P.head()
# Out:
# Date
# 2015-09-01    100.232323
# 2015-09-02    104.531181
# 2015-09-03    102.698120
# 2015-09-04    101.674576
# 2015-09-08    104.503265
# Name: Adj Close, dtype: float64

# %%
P.plot()

# %%
P.diff()        # diferences between days
# Out:
# Date
# 2015-09-01         NaN
# 2015-09-02    4.298859
# 2015-09-03   -1.833061
# 2015-09-04   -1.023544
# 2015-09-08    2.828690
#                 ...
# 2019-12-24    0.269989
# 2019-12-26    5.640015
# 2019-12-27   -0.110016
# 2019-12-30    1.720001
# 2019-12-31    2.130005
# Name: Adj Close, Length: 1091, dtype: float64

# %%
r = P.diff()/P         #cal Rate of return 
r.plot()

# %%
r[-100:].plot()        # from 100 days to now

# %%
P.rolling(window=20).mean()  # with rolling(numbers of window) to cal Moving average(20days)
# Out:
# Date
# 2015-09-01           NaN
# 2015-09-02           NaN
# 2015-09-03           NaN
# 2015-09-04           NaN
# 2015-09-08           NaN
#                  ...
# 2019-12-24    272.076997
# 2019-12-26    273.357997
# 2019-12-27    274.455997
# 2019-12-30    275.669496
# 2019-12-31    277.143996
# Name: Adj Close, Length: 1091, dtype: float64

# %%
P.plot()
P.rolling(window=20).mean().plot()
P.rolling(window=100).mean().plot()

# %%
df = web.DataReader("AMZN","yahoo", start= "2015-9-1", end= "2019-12-31")

# %%
df
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2015-09-01   510.000000   493.429993   499.140015   496.540009  3864500
# 2015-09-02   510.859985   497.720001   505.089996   510.549988  3707100
# 2015-09-03   515.840027   502.570007   514.500000   504.720001  3149700
# 2015-09-04   502.850006   495.640015   497.649994   499.000000  2692500
# 2015-09-08   518.349976   508.510010   508.690002   517.539978  3810700
# ...                 ...          ...          ...          ...      ...
# 2019-12-24  1795.569946  1787.579956  1793.810059  1789.209961   881300
# 2019-12-26  1870.459961  1799.500000  1801.010010  1868.770020  6005400
# 2019-12-27  1901.400024  1866.010010  1882.920044  1869.800049  6186600
# 2019-12-30  1884.000000  1840.619995  1874.000000  1846.890015  3674700
# 2019-12-31  1853.260010  1832.229980  1842.000000  1847.839966  2506500
#
#               Adj Close
# Date
# 2015-09-01   496.540009
# 2015-09-02   510.549988
# ...

# %%
P = df['Adj Close']

# %%
P.plot()

# %%
P.rolling(window=100).mean().plot() # with rolling(numbers of window) to cal Moving average(100days)
P.rolling(window=20).mean().plot() # with rolling(numbers of window) to cal Moving average(20days)

# %%
r = P.diff()/P         #cal Rate of return 
r.plot()

# %%
r[-50:].plot()        # from 50 days to now
